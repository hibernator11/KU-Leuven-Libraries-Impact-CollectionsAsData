# %% [markdown]
# # Postcards
#
# The digital collection [Postcards](https://kuleuven.limo.libis.be/discovery/collectionDiscovery?vid=32KUL_KUL:KULeuven&collectionId=81531489730001488&lang=en) provides a large collection of old Belgian postcards showing, amongst others, village views and a wide range of events. It is published and maintained by [KU Leuven Libraries](https://bib.kuleuven.be/english).
#
# This notebook is the result of the collaboration between KU Leuven and the [University of Alicante](https://www.ua.es/), as part of the [Impact Centre of Competence in digitisation](https://www.digitisation.eu/).

# %% [markdown]
# ### Introduction
# In this example we are going to extract additional information concerning the location of publication of the records from the title

# %% [markdown]
# ### Getting started
#
# The first thing that we need to do is importing all the libraries (Python packages) that we will need to analyse the data. Note that we are using as data a CSV file, consisting of rows and columns. In order to work with CSV files, [pandas](https://pandas.pydata.org/) is a popular Python package that or is used for working with data sets. It has functions for analyzing, cleaning, exploring, and manipulating data.

# %%
import pandas as pd

# %% [markdown]
# ### Transformation to LOD
#
# Note that the domain URL should be updated with a proper domain

# %% [markdown]
# Let's now loop the CSV file to describe the records

# %%
postcards_data = pd.read_csv("../../../20250506_CaD_jnbworkshop/Metadata-exports/Postcards/20230301_Postcards.csv", skiprows=[1])
print(postcards_data)
# Out:
#                  MMS ID                                      Uniform title  \
# 0      9990136310101488                   Belœil. Gebouwen. Kastelen. Park
# 1      9990302540101488                 Beringen. Folklore en volkscultuur
# 2      9990544990101488                                   Bilzen. Panorama
# 3      9990616780101488                             Blankenberge. Panorama
# 4      9990731350101488                              Blankenberge. Zeedijk
# ...                 ...                                                ...
# 35644  9992683362801488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35645  9992688280601488                              Antwerpen. Leysstraat
# 35646  9992688285001488        Antwerpen. Gebouwen. Algemeen. Den Botaniek
# 35647  9992704600301488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35648  9992713007101488                               Antwerpen. Suikerrui
#
#                                               Main title Variant title  \
# 0      Belœil. Le parc. Le groupe de Neptune - Het pa...           NaN
# 1      Beeringen. Grand'Place. Souvenir des Fêtes de ...           NaN
# 2                                       Bilzen. Panorama           NaN
# 3      Blankenberge. Là, tout n'est qu'ordre et beaut...           NaN
# 4      Blankenberge. Grote hotels op zeedijk - Grands...           NaN
# ...                                                  ...           ...
# 35644  Musée Royal d'Anvers. Le Jugement dernier, les...           NaN
# 35645  Antwerpen. Ingang der Leysstraat - Anvers. Ent...           NaN
# 35646                         Anvers. Rue Botanique [01]           NaN
# 35647  Musée Royal d'Anvers. Le Sauveur mort, pleuré ...           NaN
# 35648          Souvenir d'Anvers. Le Canal au Sucre [02]           NaN
#
#                 Place of publication          Publisher  \
# 0      [lieu de publication inconnu]  [éditeur inconnu]
# 1      [lieu de publication inconnu]  [éditeur inconnu]
# 2                            Brussel              Thill
# 3                          Bruxelles              Thill
# 4                          Bruxelles              Thill
# ...                              ...                ...
# 35644                         Anvers            Hermans
# 35645                      Bruxelles              Thill
# 35646                      Bruxelles               Nels
# 35647                         Anvers            Hermans
# 35648                      Bruxelles               Nels
#
#                                  Date Material type            Colour  \
# 0      [date de publication inconnue]       Graphic  Black-and-white.
# 1      [date de publication inconnue]       Graphic  Black-and-white.
# 2                            ca. 1948       Graphic            Sepia.
# 3                            ca. 1954       Graphic  Black-and-white.
# 4        [datum van uitgave onbekend]       Graphic  Black-and-white.
# ...                               ...           ...               ...
# 35644                        ca. 1913       Graphic             Brown
# 35645                        ca. 1947       Graphic             Brown
# 35646  [date de publication inconnue]       Graphic   Black-and-white
# 35647  [date de publication inconnue]       Graphic             Brown
# 35648                        ca. 1900       Graphic   Black-and-white
#
#                                             General note  \
# 0      Neptunusfontein;Kasteel van Belœil;Titelgegeve...
# 1                  Titelgegevens ontleend aan prentkaart
# 2                  Titelgegevens ontleend aan prentkaart
# 3                  Titelgegevens ontleend aan prentkaart
# 4                  Titelgegevens ontleend aan prentkaart
# ...                                                  ...
# 35644              Titelgegevens ontleend aan prentkaart
# 35645              Titelgegevens ontleend aan prentkaart
# 35646              Titelgegevens ontleend aan prentkaart
# 35647              Titelgegevens ontleend aan prentkaart
# 35648              Titelgegevens ontleend aan prentkaart
#
#       Copyright status of physical object  \
# 0                            in copyright
# 1                            in copyright
# 2                            in copyright
# 3                            in copyright
# 4                            in copyright
# ...                                   ...
# 35644                       public domain
# 35645                        in copyright
# 35646                        in copyright
# 35647                       public domain
# 35648                        in copyright
#
#                     Copyright status of digital object  \
# 0      available under copyright (restricted use only)
# 1      available under copyright (restricted use only)
# 2                            available under a licence
# 3                            available under a licence
# 4                            available under a licence
# ...                                                ...
# 35644                           available as open data
# 35645                        available under a licence
# 35646                        available under a licence
# 35647                           available as open data
# 35648                        available under a licence
#
#                        Terms of use Author (main entry)  \
# 0               gebruiksvoorwaarden                 NaN
# 1               gebruiksvoorwaarden                 NaN
# 2      licentievoorwaarden#digi0020                 NaN
# 3      licentievoorwaarden#digi0020                 NaN
# 4      licentievoorwaarden#digi0020                 NaN
# ...                             ...                 ...
# 35644           gebruiksvoorwaarden                 NaN
# 35645  licentievoorwaarden#digi0020                 NaN
# 35646  licentievoorwaarden#digi0020                 NaN
# 35647           gebruiksvoorwaarden                 NaN
# 35648  licentievoorwaarden#digi0020                 NaN
#
#                                    Author (added entry)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 35644  Bosch, Hiëronymus approximately 1450-1516 artist
# 35645                                               NaN
# 35646                                               NaN
# 35647               Rubens, Peter Paul 1577-1640 artist
# 35648                                               NaN
#
#                                              Group title Language  \
# 0      België. Provincie Henegouwen. Prentkaarten ; B...      fre
# 1      België. Provincie Limburg. Prentkaarten ; Belg...      fre
# 2      België. Provincie Limburg. Prentkaarten ; Belg...      dut
# 3      België. Provincie West-Vlaanderen. Prentkaarte...      fre
# 4      België. Provincie West-Vlaanderen. Prentkaarte...      dut
# ...                                                  ...      ...
# 35644  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35645  België. Provincie Antwerpen. Prentkaarten ; Be...      dut
# 35646  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35647  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35648  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
#
#       Country of publication  \
# 0                         \\
# 1                         \\
# 2                         \\
# 3                         \\
# 4                         \\
# ...                      ...
# 35644                     xx
# 35645                     xx
# 35646                     xx
# 35647                     xx
# 35648                     xx
#
#                                             Resolver URL  \
# 0      http://resolver.libis.be/IE2777387/representation
# 1      http://resolver.libis.be/IE2783050/representation
# 2      http://resolver.libis.be/IE2785913/representation
# 3      http://resolver.libis.be/IE2786767/representation
# 4      http://resolver.libis.be/IE2788279/representation
# ...                                                  ...
# 35644  http://resolver.libis.be/IE16587223/representa...
# 35645  http://resolver.libis.be/IE16350487/representa...
# 35646  http://resolver.libis.be/IE16350424/representa...
# 35647  http://resolver.libis.be/IE16588609/representa...
# 35648  http://resolver.libis.be/IE16462941/representa...
#
#                   Label (Library Call number)
# 0      KU Leuven Libraries BIBC BRES GP002180
# 1      KU Leuven Libraries BIBC BRES GP003454
# 2      KU Leuven Libraries BIBC BRES GP004279
# 3      KU Leuven Libraries BIBC BRES GP004401
# 4      KU Leuven Libraries BIBC BRES GP004617
# ...                                       ...
# 35644  KU Leuven Libraries BCOL BRES GP101210
# 35645  KU Leuven Libraries BCOL BRES GP106321
# 35646  KU Leuven Libraries BCOL BRES GP106314
# 35647  KU Leuven Libraries BCOL BRES GP101367
# 35648  KU Leuven Libraries BCOL BRES GP107464
#
# [35649 rows x 20 columns]

# %% [markdown]
# Let's now transform the data

# %%
for index, row in postcards_data.iterrows():
    location = row['Uniform title'].split(".")[0]
    print(location)

    if index == 5: # testing purposes
        break
# Out:
# Belœil
# Beringen
# Bilzen
# Blankenberge
# Blankenberge
# Borgerhout

# %% [markdown]
# Let's try to create a new column with the extracted data.
# First we define a function that we will apply to all the rows.

# %%
# Function to extract the location from the title
def extract_location(title):
    result = ''
    try:
        if type(title) is str:
            result = title.split(".")[0]
    except:
        print('Error, the title does not contain the location:' + title)
    return result

postcards_data['Location title'] = postcards_data['Uniform title'].apply(extract_location)
print(postcards_data)
# Out:
#                  MMS ID                                      Uniform title  \
# 0      9990136310101488                   Belœil. Gebouwen. Kastelen. Park
# 1      9990302540101488                 Beringen. Folklore en volkscultuur
# 2      9990544990101488                                   Bilzen. Panorama
# 3      9990616780101488                             Blankenberge. Panorama
# 4      9990731350101488                              Blankenberge. Zeedijk
# ...                 ...                                                ...
# 35644  9992683362801488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35645  9992688280601488                              Antwerpen. Leysstraat
# 35646  9992688285001488        Antwerpen. Gebouwen. Algemeen. Den Botaniek
# 35647  9992704600301488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35648  9992713007101488                               Antwerpen. Suikerrui
#
#                                               Main title Variant title  \
# 0      Belœil. Le parc. Le groupe de Neptune - Het pa...           NaN
# 1      Beeringen. Grand'Place. Souvenir des Fêtes de ...           NaN
# 2                                       Bilzen. Panorama           NaN
# 3      Blankenberge. Là, tout n'est qu'ordre et beaut...           NaN
# 4      Blankenberge. Grote hotels op zeedijk - Grands...           NaN
# ...                                                  ...           ...
# 35644  Musée Royal d'Anvers. Le Jugement dernier, les...           NaN
# 35645  Antwerpen. Ingang der Leysstraat - Anvers. Ent...           NaN
# 35646                         Anvers. Rue Botanique [01]           NaN
# 35647  Musée Royal d'Anvers. Le Sauveur mort, pleuré ...           NaN
# 35648          Souvenir d'Anvers. Le Canal au Sucre [02]           NaN
#
#                 Place of publication          Publisher  \
# 0      [lieu de publication inconnu]  [éditeur inconnu]
# 1      [lieu de publication inconnu]  [éditeur inconnu]
# 2                            Brussel              Thill
# 3                          Bruxelles              Thill
# 4                          Bruxelles              Thill
# ...                              ...                ...
# 35644                         Anvers            Hermans
# 35645                      Bruxelles              Thill
# 35646                      Bruxelles               Nels
# 35647                         Anvers            Hermans
# 35648                      Bruxelles               Nels
#
#                                  Date Material type            Colour  \
# 0      [date de publication inconnue]       Graphic  Black-and-white.
# 1      [date de publication inconnue]       Graphic  Black-and-white.
# 2                            ca. 1948       Graphic            Sepia.
# 3                            ca. 1954       Graphic  Black-and-white.
# 4        [datum van uitgave onbekend]       Graphic  Black-and-white.
# ...                               ...           ...               ...
# 35644                        ca. 1913       Graphic             Brown
# 35645                        ca. 1947       Graphic             Brown
# 35646  [date de publication inconnue]       Graphic   Black-and-white
# 35647  [date de publication inconnue]       Graphic             Brown
# 35648                        ca. 1900       Graphic   Black-and-white
#
#                                             General note  ...  \
# 0      Neptunusfontein;Kasteel van Belœil;Titelgegeve...  ...
# 1                  Titelgegevens ontleend aan prentkaart  ...
# 2                  Titelgegevens ontleend aan prentkaart  ...
# 3                  Titelgegevens ontleend aan prentkaart  ...
# 4                  Titelgegevens ontleend aan prentkaart  ...
# ...                                                  ...  ...
# 35644              Titelgegevens ontleend aan prentkaart  ...
# 35645              Titelgegevens ontleend aan prentkaart  ...
# 35646              Titelgegevens ontleend aan prentkaart  ...
# 35647              Titelgegevens ontleend aan prentkaart  ...
# 35648              Titelgegevens ontleend aan prentkaart  ...
#
#                     Copyright status of digital object  \
# 0      available under copyright (restricted use only)
# 1      available under copyright (restricted use only)
# 2                            available under a licence
# 3                            available under a licence
# 4                            available under a licence
# ...                                                ...
# 35644                           available as open data
# 35645                        available under a licence
# 35646                        available under a licence
# 35647                           available as open data
# 35648                        available under a licence
#
#                        Terms of use Author (main entry)  \
# 0               gebruiksvoorwaarden                 NaN
# 1               gebruiksvoorwaarden                 NaN
# 2      licentievoorwaarden#digi0020                 NaN
# 3      licentievoorwaarden#digi0020                 NaN
# 4      licentievoorwaarden#digi0020                 NaN
# ...                             ...                 ...
# 35644           gebruiksvoorwaarden                 NaN
# 35645  licentievoorwaarden#digi0020                 NaN
# 35646  licentievoorwaarden#digi0020                 NaN
# 35647           gebruiksvoorwaarden                 NaN
# 35648  licentievoorwaarden#digi0020                 NaN
#
#                                    Author (added entry)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 35644  Bosch, Hiëronymus approximately 1450-1516 artist
# 35645                                               NaN
# 35646                                               NaN
# 35647               Rubens, Peter Paul 1577-1640 artist
# 35648                                               NaN
#
#                                              Group title Language  \
# 0      België. Provincie Henegouwen. Prentkaarten ; B...      fre
# 1      België. Provincie Limburg. Prentkaarten ; Belg...      fre
# 2      België. Provincie Limburg. Prentkaarten ; Belg...      dut
# 3      België. Provincie West-Vlaanderen. Prentkaarte...      fre
# 4      België. Provincie West-Vlaanderen. Prentkaarte...      dut
# ...                                                  ...      ...
# 35644  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35645  België. Provincie Antwerpen. Prentkaarten ; Be...      dut
# 35646  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35647  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35648  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
#
#       Country of publication  \
# 0                         \\
# 1                         \\
# 2                         \\
# 3                         \\
# 4                         \\
# ...                      ...
# 35644                     xx
# 35645                     xx
# 35646                     xx
# 35647                     xx
# 35648                     xx
#
#                                             Resolver URL  \
# 0      http://resolver.libis.be/IE2777387/representation
# 1      http://resolver.libis.be/IE2783050/representation
# 2      http://resolver.libis.be/IE2785913/representation
# 3      http://resolver.libis.be/IE2786767/representation
# 4      http://resolver.libis.be/IE2788279/representation
# ...                                                  ...
# 35644  http://resolver.libis.be/IE16587223/representa...
# 35645  http://resolver.libis.be/IE16350487/representa...
# 35646  http://resolver.libis.be/IE16350424/representa...
# 35647  http://resolver.libis.be/IE16588609/representa...
# 35648  http://resolver.libis.be/IE16462941/representa...
#
#                   Label (Library Call number) Location title
# 0      KU Leuven Libraries BIBC BRES GP002180         Belœil
# 1      KU Leuven Libraries BIBC BRES GP003454       Beringen
# 2      KU Leuven Libraries BIBC BRES GP004279         Bilzen
# 3      KU Leuven Libraries BIBC BRES GP004401   Blankenberge
# 4      KU Leuven Libraries BIBC BRES GP004617   Blankenberge
# ...                                       ...            ...
# 35644  KU Leuven Libraries BCOL BRES GP101210      Antwerpen
# 35645  KU Leuven Libraries BCOL BRES GP106321      Antwerpen
# 35646  KU Leuven Libraries BCOL BRES GP106314      Antwerpen
# 35647  KU Leuven Libraries BCOL BRES GP101367      Antwerpen
# 35648  KU Leuven Libraries BCOL BRES GP107464      Antwerpen
#
# [35649 rows x 21 columns]

# %%
print(postcards_data['Location title'].unique())
# Out:
# ['Belœil' 'Beringen' 'Bilzen' ... '' 'Bois-de-Lessines (Lessines)'
#  'Soye (Floreffe)']

# %%
print(postcards_data['Location title'].nunique())
# Out:
# 1155

# %%
print(postcards_data['Location title'])
# Out:
# 0              Belœil
# 1            Beringen
# 2              Bilzen
# 3        Blankenberge
# 4        Blankenberge
#              ...
# 35644       Antwerpen
# 35645       Antwerpen
# 35646       Antwerpen
# 35647       Antwerpen
# 35648       Antwerpen
# Name: Location title, Length: 35649, dtype: object

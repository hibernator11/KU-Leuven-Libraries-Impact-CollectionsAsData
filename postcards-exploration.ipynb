# %%
import pandas as pd

# Read the CSV file
postcards_data = pd.read_csv("20250506_CaD_jnbworkshop/Metadata-exports/Postcards/20230301_Postcards.csv")

# View the first 5 rows
postcards_data.head()
# Out:
#              MMS ID                       Uniform title  \
# 0                 1                               130$a
# 1  9990136310101488    Belœil. Gebouwen. Kastelen. Park
# 2  9990302540101488  Beringen. Folklore en volkscultuur
# 3  9990544990101488                    Bilzen. Panorama
# 4  9990616780101488              Blankenberge. Panorama
#
#                                           Main title Variant title  \
# 0                                              245$a         246$a
# 1  Belœil. Le parc. Le groupe de Neptune - Het pa...           NaN
# 2  Beeringen. Grand'Place. Souvenir des Fêtes de ...           NaN
# 3                                   Bilzen. Panorama           NaN
# 4  Blankenberge. Là, tout n'est qu'ordre et beaut...           NaN
#
#             Place of publication          Publisher  \
# 0                          264$a              264$b
# 1  [lieu de publication inconnu]  [éditeur inconnu]
# 2  [lieu de publication inconnu]  [éditeur inconnu]
# 3                        Brussel              Thill
# 4                      Bruxelles              Thill
#
#                              Date Material type            Colour  \
# 0                           264$c         340$a             340$o
# 1  [date de publication inconnue]       Graphic  Black-and-white.
# 2  [date de publication inconnue]       Graphic  Black-and-white.
# 3                        ca. 1948       Graphic            Sepia.
# 4                        ca. 1954       Graphic  Black-and-white.
#
#                                         General note  \
# 0                                              500$a
# 1  Neptunusfontein;Kasteel van Belœil;Titelgegeve...
# 2              Titelgegevens ontleend aan prentkaart
# 3              Titelgegevens ontleend aan prentkaart
# 4              Titelgegevens ontleend aan prentkaart
#
#   Copyright status of physical object  \
# 0                               542$l
# 1                        in copyright
# 2                        in copyright
# 3                        in copyright
# 4                        in copyright
#
#                 Copyright status of digital object  \
# 0                                            542$n
# 1  available under copyright (restricted use only)
# 2  available under copyright (restricted use only)
# 3                        available under a licence
# 4                        available under a licence
#
#                    Terms of use  \
# 0                         542$u
# 1           gebruiksvoorwaarden
# 2           gebruiksvoorwaarden
# 3  licentievoorwaarden#digi0020
# 4  licentievoorwaarden#digi0020
#
#                                  Author (main entry)  \
# 0  100$a Name 100$d biographical data 100$e relat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                 Author (added entry)  \
# 0  700$a Name 700$d biographical data 700$e relat...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Group title  Language  \
# 0                                              830$a  008$35:3
# 1  België. Provincie Henegouwen. Prentkaarten ; B...       fre
# 2  België. Provincie Limburg. Prentkaarten ; Belg...       fre
# 3  België. Provincie Limburg. Prentkaarten ; Belg...       dut
# 4  België. Provincie West-Vlaanderen. Prentkaarte...       fre
#
#   Country of publication                                       Resolver URL  \
# 0               008$15:2                                              856$u
# 1                     \\  http://resolver.libis.be/IE2777387/representation
# 2                     \\  http://resolver.libis.be/IE2783050/representation
# 3                     \\  http://resolver.libis.be/IE2785913/representation
# 4                     \\  http://resolver.libis.be/IE2786767/representation
#
#               Label (Library Call number)
# 0                                   856$y
# 1  KU Leuven Libraries BIBC BRES GP002180
# 2  KU Leuven Libraries BIBC BRES GP003454
# 3  KU Leuven Libraries BIBC BRES GP004279
# 4  KU Leuven Libraries BIBC BRES GP004401

# %%
print(postcards_data)
# Out:
#                  MMS ID                                      Uniform title  \
# 0                     1                                              130$a
# 1      9990136310101488                   Belœil. Gebouwen. Kastelen. Park
# 2      9990302540101488                 Beringen. Folklore en volkscultuur
# 3      9990544990101488                                   Bilzen. Panorama
# 4      9990616780101488                             Blankenberge. Panorama
# ...                 ...                                                ...
# 35645  9992683362801488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35646  9992688280601488                              Antwerpen. Leysstraat
# 35647  9992688285001488        Antwerpen. Gebouwen. Algemeen. Den Botaniek
# 35648  9992704600301488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35649  9992713007101488                               Antwerpen. Suikerrui
#
#                                               Main title Variant title  \
# 0                                                  245$a         246$a
# 1      Belœil. Le parc. Le groupe de Neptune - Het pa...           NaN
# 2      Beeringen. Grand'Place. Souvenir des Fêtes de ...           NaN
# 3                                       Bilzen. Panorama           NaN
# 4      Blankenberge. Là, tout n'est qu'ordre et beaut...           NaN
# ...                                                  ...           ...
# 35645  Musée Royal d'Anvers. Le Jugement dernier, les...           NaN
# 35646  Antwerpen. Ingang der Leysstraat - Anvers. Ent...           NaN
# 35647                         Anvers. Rue Botanique [01]           NaN
# 35648  Musée Royal d'Anvers. Le Sauveur mort, pleuré ...           NaN
# 35649          Souvenir d'Anvers. Le Canal au Sucre [02]           NaN
#
#                 Place of publication          Publisher  \
# 0                              264$a              264$b
# 1      [lieu de publication inconnu]  [éditeur inconnu]
# 2      [lieu de publication inconnu]  [éditeur inconnu]
# 3                            Brussel              Thill
# 4                          Bruxelles              Thill
# ...                              ...                ...
# 35645                         Anvers            Hermans
# 35646                      Bruxelles              Thill
# 35647                      Bruxelles               Nels
# 35648                         Anvers            Hermans
# 35649                      Bruxelles               Nels
#
#                                  Date Material type            Colour  \
# 0                               264$c         340$a             340$o
# 1      [date de publication inconnue]       Graphic  Black-and-white.
# 2      [date de publication inconnue]       Graphic  Black-and-white.
# 3                            ca. 1948       Graphic            Sepia.
# 4                            ca. 1954       Graphic  Black-and-white.
# ...                               ...           ...               ...
# 35645                        ca. 1913       Graphic             Brown
# 35646                        ca. 1947       Graphic             Brown
# 35647  [date de publication inconnue]       Graphic   Black-and-white
# 35648  [date de publication inconnue]       Graphic             Brown
# 35649                        ca. 1900       Graphic   Black-and-white
#
#                                             General note  \
# 0                                                  500$a
# 1      Neptunusfontein;Kasteel van Belœil;Titelgegeve...
# 2                  Titelgegevens ontleend aan prentkaart
# 3                  Titelgegevens ontleend aan prentkaart
# 4                  Titelgegevens ontleend aan prentkaart
# ...                                                  ...
# 35645              Titelgegevens ontleend aan prentkaart
# 35646              Titelgegevens ontleend aan prentkaart
# 35647              Titelgegevens ontleend aan prentkaart
# 35648              Titelgegevens ontleend aan prentkaart
# 35649              Titelgegevens ontleend aan prentkaart
#
#       Copyright status of physical object  \
# 0                                   542$l
# 1                            in copyright
# 2                            in copyright
# 3                            in copyright
# 4                            in copyright
# ...                                   ...
# 35645                       public domain
# 35646                        in copyright
# 35647                        in copyright
# 35648                       public domain
# 35649                        in copyright
#
#                     Copyright status of digital object  \
# 0                                                542$n
# 1      available under copyright (restricted use only)
# 2      available under copyright (restricted use only)
# 3                            available under a licence
# 4                            available under a licence
# ...                                                ...
# 35645                           available as open data
# 35646                        available under a licence
# 35647                        available under a licence
# 35648                           available as open data
# 35649                        available under a licence
#
#                        Terms of use  \
# 0                             542$u
# 1               gebruiksvoorwaarden
# 2               gebruiksvoorwaarden
# 3      licentievoorwaarden#digi0020
# 4      licentievoorwaarden#digi0020
# ...                             ...
# 35645           gebruiksvoorwaarden
# 35646  licentievoorwaarden#digi0020
# 35647  licentievoorwaarden#digi0020
# 35648           gebruiksvoorwaarden
# 35649  licentievoorwaarden#digi0020
#
#                                      Author (main entry)  \
# 0      100$a Name 100$d biographical data 100$e relat...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 35645                                                NaN
# 35646                                                NaN
# 35647                                                NaN
# 35648                                                NaN
# 35649                                                NaN
#
#                                     Author (added entry)  \
# 0      700$a Name 700$d biographical data 700$e relat...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 35645   Bosch, Hiëronymus approximately 1450-1516 artist
# 35646                                                NaN
# 35647                                                NaN
# 35648                Rubens, Peter Paul 1577-1640 artist
# 35649                                                NaN
#
#                                              Group title  Language  \
# 0                                                  830$a  008$35:3
# 1      België. Provincie Henegouwen. Prentkaarten ; B...       fre
# 2      België. Provincie Limburg. Prentkaarten ; Belg...       fre
# 3      België. Provincie Limburg. Prentkaarten ; Belg...       dut
# 4      België. Provincie West-Vlaanderen. Prentkaarte...       fre
# ...                                                  ...       ...
# 35645  België. Provincie Antwerpen. Prentkaarten ; Be...       fre
# 35646  België. Provincie Antwerpen. Prentkaarten ; Be...       dut
# 35647  België. Provincie Antwerpen. Prentkaarten ; Be...       fre
# 35648  België. Provincie Antwerpen. Prentkaarten ; Be...       fre
# 35649  België. Provincie Antwerpen. Prentkaarten ; Be...       fre
#
#       Country of publication  \
# 0                   008$15:2
# 1                         \\
# 2                         \\
# 3                         \\
# 4                         \\
# ...                      ...
# 35645                     xx
# 35646                     xx
# 35647                     xx
# 35648                     xx
# 35649                     xx
#
#                                             Resolver URL  \
# 0                                                  856$u
# 1      http://resolver.libis.be/IE2777387/representation
# 2      http://resolver.libis.be/IE2783050/representation
# 3      http://resolver.libis.be/IE2785913/representation
# 4      http://resolver.libis.be/IE2786767/representation
# ...                                                  ...
# 35645  http://resolver.libis.be/IE16587223/representa...
# 35646  http://resolver.libis.be/IE16350487/representa...
# 35647  http://resolver.libis.be/IE16350424/representa...
# 35648  http://resolver.libis.be/IE16588609/representa...
# 35649  http://resolver.libis.be/IE16462941/representa...
#
#                   Label (Library Call number)
# 0                                       856$y
# 1      KU Leuven Libraries BIBC BRES GP002180
# 2      KU Leuven Libraries BIBC BRES GP003454
# 3      KU Leuven Libraries BIBC BRES GP004279
# 4      KU Leuven Libraries BIBC BRES GP004401
# ...                                       ...
# 35645  KU Leuven Libraries BCOL BRES GP101210
# 35646  KU Leuven Libraries BCOL BRES GP106321
# 35647  KU Leuven Libraries BCOL BRES GP106314
# 35648  KU Leuven Libraries BCOL BRES GP101367
# 35649  KU Leuven Libraries BCOL BRES GP107464
#
# [35650 rows x 20 columns]

# %%
postcards_data.tail()
# Out:
#                  MMS ID                                      Uniform title  \
# 35645  9992683362801488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35646  9992688280601488                              Antwerpen. Leysstraat
# 35647  9992688285001488        Antwerpen. Gebouwen. Algemeen. Den Botaniek
# 35648  9992704600301488  Antwerpen. Beelden en objecten. Koninklijk Mus...
# 35649  9992713007101488                               Antwerpen. Suikerrui
#
#                                               Main title Variant title  \
# 35645  Musée Royal d'Anvers. Le Jugement dernier, les...           NaN
# 35646  Antwerpen. Ingang der Leysstraat - Anvers. Ent...           NaN
# 35647                         Anvers. Rue Botanique [01]           NaN
# 35648  Musée Royal d'Anvers. Le Sauveur mort, pleuré ...           NaN
# 35649          Souvenir d'Anvers. Le Canal au Sucre [02]           NaN
#
#       Place of publication Publisher                            Date  \
# 35645               Anvers   Hermans                        ca. 1913
# 35646            Bruxelles     Thill                        ca. 1947
# 35647            Bruxelles      Nels  [date de publication inconnue]
# 35648               Anvers   Hermans  [date de publication inconnue]
# 35649            Bruxelles      Nels                        ca. 1900
#
#       Material type           Colour                           General note  \
# 35645       Graphic            Brown  Titelgegevens ontleend aan prentkaart
# 35646       Graphic            Brown  Titelgegevens ontleend aan prentkaart
# 35647       Graphic  Black-and-white  Titelgegevens ontleend aan prentkaart
# 35648       Graphic            Brown  Titelgegevens ontleend aan prentkaart
# 35649       Graphic  Black-and-white  Titelgegevens ontleend aan prentkaart
#
#       Copyright status of physical object Copyright status of digital object  \
# 35645                       public domain             available as open data
# 35646                        in copyright          available under a licence
# 35647                        in copyright          available under a licence
# 35648                       public domain             available as open data
# 35649                        in copyright          available under a licence
#
#                        Terms of use Author (main entry)  \
# 35645           gebruiksvoorwaarden                 NaN
# 35646  licentievoorwaarden#digi0020                 NaN
# 35647  licentievoorwaarden#digi0020                 NaN
# 35648           gebruiksvoorwaarden                 NaN
# 35649  licentievoorwaarden#digi0020                 NaN
#
#                                    Author (added entry)  \
# 35645  Bosch, Hiëronymus approximately 1450-1516 artist
# 35646                                               NaN
# 35647                                               NaN
# 35648               Rubens, Peter Paul 1577-1640 artist
# 35649                                               NaN
#
#                                              Group title Language  \
# 35645  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35646  België. Provincie Antwerpen. Prentkaarten ; Be...      dut
# 35647  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35648  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
# 35649  België. Provincie Antwerpen. Prentkaarten ; Be...      fre
#
#       Country of publication  \
# 35645                     xx
# 35646                     xx
# 35647                     xx
# 35648                     xx
# 35649                     xx
#
#                                             Resolver URL  \
# 35645  http://resolver.libis.be/IE16587223/representa...
# 35646  http://resolver.libis.be/IE16350487/representa...
# 35647  http://resolver.libis.be/IE16350424/representa...
# 35648  http://resolver.libis.be/IE16588609/representa...
# 35649  http://resolver.libis.be/IE16462941/representa...
#
#                   Label (Library Call number)
# 35645  KU Leuven Libraries BCOL BRES GP101210
# 35646  KU Leuven Libraries BCOL BRES GP106321
# 35647  KU Leuven Libraries BCOL BRES GP106314
# 35648  KU Leuven Libraries BCOL BRES GP101367
# 35649  KU Leuven Libraries BCOL BRES GP107464

# %%
# Get the unique values of 'Place of publication' column
unique_values = postcards_data['Place of publication'].unique()
print(unique_values)
# Out:
# ['264$a' '[lieu de publication inconnu]' 'Brussel' 'Bruxelles' 'Anvers'
#  '[plaats van uitgave onbekend]' 'Gand' 'Aarschot'
#  '[place of publication not identified]' 'Antwerpen' '[Bruxelles]'
#  'Cappellen' 'Brugge' 'Paris' 'Francfort' 'Berchem' 'Bourg-Léopold'
#  'Dresden' 'Frankfurt a/M' 'Brux.' 'Dresde' 'Hasselt' 'Ostende' 'Liége'
#  'Francfort s/M' 'Malmedy' 'Aalst' 'Leipzig' 'Huy' 'Furnes' 'Rheydt'
#  'Chimay' '[Bruxelles' 'Malmédy' 'Laeken' 'Bruges' 'St-Idesbald' 'Virton'
#  'Antw.' 'Amsterdam' 'Bruselles' 'België' 'Hoogstraeten' 'La Hulpe' 'Spa'
#  'Lokeren' 'Koksijde' 'Malines' 'Audenarde' 'S.l.' 'Dresda' 'Arlon'
#  'Mariakerke-lez-Gand' 'Moresnet' 'Mechelen' 'München' 'Athus' 'Mulhouse'
#  '[Libin]' 'Bruxellen' 'bruxelles' '[Brugge]' '[Brussel]' 'Andenne'
#  'Uccle' 'Hoogstraten' 'Rethy' 'Tirlemont' 'Brasschaat' 'Belgium'
#  'Aix-la-Chapelle' 'Antwerpe' 'Gent' 'Feldmeilen' 'Köln a. Rh.' 'Antwerp'
#  'Middelkerke' 'Alost' 'Frankfurt' 'Namur' '\u202c[Bruxelles]' 'Bevernage'
#  'Anderlecht' 'Aywaille' 'Gladbach' 'Anver'
#  "Temsche. Land van Waes. Dichtgevroren Schelde 1890-1891 - Tamise. Pays de Waes. L'Escaut gelé pendant l'hiver 1890-1891;Huy"
#  'Ghistel' 'Dadizeele' '[Brussel' 'Italy' 'Meerhout' 'frankfurt a/M'
#  'Alle s/Semois' 'Moresnet;[lieu de publication inconnu]' 'Bruxellles'
#  'Aeltre' 'Paris-Corbeil' 'Liège' 'Arlon-Aubel' 'Oostende' 'Berlin'
#  'Bruxelle' 'Aachen' 'Puers' 'Mulhouse-Dornach'
#  '[lieu de publication inconnu];Moresnet' 'Kemmel' 'Nederbrakel'
#  'Molenbeek' 'Ghlin' 'Maeseyck' 'Ostend']

# %%
# Get the unique values of 'Material type' column
unique_values = postcards_data['Material type'].unique()
print(unique_values)
# Out:
# ['340$a' 'Graphic' nan 'Graphic   {dollar}{dollar}  Black-and-white'
#  'Graphic (unspecified)' 'Graphic;Online']

# %%
# Get the unique values of 'Date' column
unique_values = postcards_data['Date'].unique()
print(unique_values)
# Out:
# ['264$c' '[date de publication inconnue]' 'ca. 1948' 'ca. 1954'
#  '[datum van uitgave onbekend]' 'ca. 1908' 'ca. 1910'
#  '[date de publication inconnu]' 'ca.1915' 'ca. 1923' 'ca. 1906'
#  'ca. 1965' 'ca. 1938' 'ca.1922' '[date of publication not identified]'
#  'CA.1951' 'ca.1961' 'ca.1950' 'ca.1901' '1933' 'ca. 1932' '1927'
#  'ca. 1937' 'ca. 1920' 'ca. 1901' 'ca. 190x' 'ca. 1927' 'ca. 1913'
#  'ca. 1966' 'ca. 1904' 'ca. 1902' 'ca. 1924' 'ca. 1935' 'ca. 1905x'
#  'ca. 1953' 'ca. 1907' 'ca. 1903' 'ca. 1919' 'ca. 1911' 'ca.1908'
#  'ca.1910' '1923' 'ca. 1956' 'ca. 1900' '1899?' 'ca. 1905' 'ca.1959'
#  'ca. 191x' 'ca. 1930' 'ca.1973' 'ca.1919' 'ca.1956' '1899' '1941'
#  'ca.1926' 'ca. 1955' 'ca. 1934' 'ca. 1914' 'ca.1913' 'ca.1903' '1953'
#  'ca.1927' '1987' 'ca.1921' 'ca. 1909' 'ca. 196x' 'ca. 1912' 'ca. 1899'
#  'ca.1907' 'ca. 197x' 'ca.1898' 'ca.1899' '1922' 'ca.1920' 'Ca. 1935'
#  'ca. 1928' 'ca. 1897' 'ca. 1898' 'ca.1900' 'ca. 1925' 'ca. 1929' '1934'
#  'ca. 1964' 'ca. 1960' '1959' '1938' 'ca. 1921' 'ca. 1950' 'ca. 1958'
#  'ca. 1961' 'ca. 1949' 'ca.1930' 'ca.1975' 'ca. 1962' 'ca.1936' '1904'
#  'ca. 1972' 'ca. 1939' 'ca. 1936' 'ca. 1931' 'ca.1914' 'ca.1902' 'ca.1904'
#  'ca. 1959' 'ca. 1945' 'ca. 1915' 'ca.1912' 'ca.1970' 'ca. 1917' 'ca.190x'
#  'Ca. 1913' 'ca. 1922' 'ca.1909' 'ca.1911' '1919' 'ca.1924' 'ca.1906'
#  'ca.1905' 'ca. 1963' 'Ca.1926' 'ca. 1968' 'ca. 190X' 'ca. 194X' 'ca.1951'
#  '1932' 'ca. 1943' 'ca. 1926' 'ca. 1951' '1929' 'ca.1923' '1906'
#  'ca. 192x' 'ca. 1933' 'ca.1948' 'ca.1933' '1905' '1909' 'ca. 1944'
#  '1972?' '1903' '1901' '1900' 'ca. 1976' 'Ca. 1937' 'ca. 197X' 'ca. 193x'
#  'ca. 189X' 'ca. 1918' 'ca. 1957' 'ca.1934' '1902' '1965' 'ca.1960' '1912'
#  'ca. 1967' 'ca.1964' '1911' 'ca.1917' '1907' 'Ca. 1905' 'ca.1931'
#  'ca.1928' '1908' '1928' '1955' 'ca.1947' '1920' '1943' '1911?' '1926'
#  '[publisher not identified]' 'ca. 1974' '190x' '1947' 'ca.1932' 'ca.1935'
#  'ca.1925' '1910' 'Ca. 1930' 'Ca.  1907' 'ca. 1947' '1898' '1925' '1924'
#  'Ca. 1941' 'ca. 1969' 'ca.1962' 'ca. 1952' 'ca.1955' 'ca.190X' 'ca.1965'
#  '194x' 'ca.1954' 'ca. 1946' 'ca.1939' '1935' 'ca. 1941' 'ca. 1916'
#  'ca.1952' '1960' 'ca. 1896' 'ca.1968' 'ca. 190c' 'ca. 19068' '19ux'
#  'ca.1946' 'ca.1929' 'Ca.1941' '1908?' 'ca. 194x' 'ca.1971' 'ca. 1970'
#  '19899' 'ca. 195x' '1937' '1964' 'ca. 1971' '1961' 'Ca. 1920' 'Ca. 1908'
#  'ca.1992' 'ca. 1942' 'ca.1967' '1936' 'ca. 1977' 'ca.1938' 'ca.1949'
#  'ca.1963' 'ca.1937' '1939' 'Ca. 1919' 'ca.1957' 'ca.1942' 'ca.1953'
#  '1914' 'ca.1958' 'Ca. 1912' 'ca. 1990' 'ca. 1975' 'ca. 1980' '1930'
#  '1913' '1921' 'ca.1974' 'ca.1605' 'ca.1943' 'ca.1981' 'ca.1966' '1957'
#  'ca.193X' 'ca. 18xx' 'ca.1916' 'ca.1969' '1924?' 'ca. 190u' 'ca. 19xx'
#  '1952' 'ca.197X' '1948' '1967' 'ca. 1973' '1958' 'ca. 1978' 'ca. 192X'
#  'ca.1897' '1970' 'ca .1965' 'ca.1941' 'ca .1919' 'Ca. 1927' 'Ca. 1901'
#  'Ca. 193' 'ca.1918' 'ca.1985' '1900?' 'ca.01908' '192x' 'Ca. 1903' '1956'
#  '194' 'ca. 1891' 'ca.1945' 'ca.1976' 'ca. 19028' 'ca.1977' '1949'
#  'ca.1972' 'Ca. 1906' '195x' '1905?' '1940' 'ca. 1940' 'Ca. 1910'
#  'ca. 1894' 'ca. 189x' '1944' 'Ca.1942' 'ca. 1986' '[éditeur inconnu]'
#  'Ca.1958' 'ca.194X' 'ca. 193X' 'ca.1979' '1955?' '1902?' '1909?' '1929?'
#  'ca. 1979' '192X' 'Ca. 1900' 'Ca. 1909'
#  '[date of publication not identified] [date of publication not identified]'
#  'Ca. 1928' 'ca. 1902;ca' 'Ca. 1931' '1951'
#  '[date de publication inconnue' '19080' 'ca.1940'
#  '[date de publication inconnue];[date de publication inconnue]' '1903?'
#  'Ca. 1970' 'Ca. 1925' 'ca. 196X' 'ca. 19XX' '193x' 'Ca. 1902' 'ca. 1890'
#  '1950' 'ca.192x' 'ca. 191X' '[date de publication inconnue]\u202a'
#  'ca. 1989' 'ca. 1847' 'Ca. 1907' 'ca 1901' '198x' '1907?' '1966' '1945'
#  'ca. 195X' '19xx' 'Ca. 1921' 'ca.1987' '1939?' 'Ca. 1934' '1906?' '1962'
#  'Ca.1952' 'ca. 1937?' 'ca. 1948;ca. 1948' 'ca.1944' 'ca. 19x4' '1915'
#  'Ca. 192x' '1913?' 'ca .1966' 'ca. 1892' '1931' '1968' '1945?' '1963'
#  'ca. 1984' '1918' 'ca. 16912' 'Ca. 190X' 'ca.1896' 'ca. 190?']

# %%
num_of_rows = len(postcards_data)

print(f"The number of rows is {num_of_rows}")
# Out:
# The number of rows is 35650
